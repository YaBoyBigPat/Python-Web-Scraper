# %%
import requests
import os
import shutil
from bs4 import BeautifulSoup
import pandas as pd
import lxml
import time
import html5lib

# %%
years = list(range(1992, 2023))

# %% [markdown]
# Code below can be used or deleated
# __________________________________________

# %%
url_start = "https://www.basketball-reference.com/awards/awards_{}.html"

dfs = []

for year in years:
    url = url_start.format(year)
    data = requests.get(url)
    time.sleep(20)  # Add a delay here
    
    if data.status_code == 200:
        with open("mvp/{}.html".format(year), "w+", encoding="utf-8") as f:
            f.write(data.text)
        
        with open("mvp/{}.html".format(year)) as f:
            page = f.read()

        soup = BeautifulSoup(page, 'html.parser')
        
        header = soup.find('tr', class_="over_header")
        if header:
            header.decompose()
            
        mvp_table_list = soup.find_all(id="mvp")
        
        if len(mvp_table_list) > 0:
            mvp_table = mvp_table_list[0]
            mvp_df = pd.read_html(str(mvp_table), header=0)[0]
            mvp_df["Year"] = year
            dfs.append(mvp_df)
    else:
        print(f"Failed to fetch data for year {year}. Status code: {data.status_code}")

# After the loop, you can concatenate the dataframes
mvps = pd.concat(dfs)

# %% [markdown]
# _______________________________________________________

# %%
url_start = "https://www.basketball-reference.com/awards/awards_{}.html"

for year in years:
    url = url_start.format(year)
    data = requests.get(url)
    time.sleep(6)
    with open("mvp/{}.html".format(year), "w+", encoding="utf-8") as f:
        f.write(data.text.encode('ascii', 'ignore').decode('ascii'))

# %%
with open("mvp/1992.html") as f:
    page = f.read()
    time.sleep(10)
soup = BeautifulSoup(page, 'html.parser')
soup.find('tr', class_="over_header").decompose()

# %%
mvp_table = soup.find_all(id="mvp")[0]

# %%
mvp_1992 = pd.read_html(str(mvp_table), header=0)[0]

# %%
dfs = []
for year in years:
    with open("mvp/{}.html".format(year)) as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    
    soup.find('tr', class_="over_header").decompose()
    mvp_table = soup.find_all(id="mvp")[0]
    mvp_df = pd.read_html(str(mvp_table))[0]
    mvp_df["Year"] = year
    dfs.append(mvp_df)
time.sleep(20)

# %%
mvps = pd.concat(dfs)

# %%
mvps.head()
# Out:
#   Rank          Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 0    1  Michael Jordan   28  CHI   80.0    900.0      960  0.938  80  38.8
# 1    2   Clyde Drexler   29  POR   12.0    561.0      960  0.584  76  36.2
# 2    3  David Robinson   26  SAS    2.0    337.0      960  0.351  68  37.7
# 3    4     Karl Malone   28  UTA    1.0    262.0      960  0.273  81  37.7
# 4    5   Patrick Ewing   29  NYK    0.0    100.0      960  0.104  82  38.4
#
#    ...   TRB  AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# 0  ...   6.4  6.1  2.3  0.9  0.519  0.270  0.832  17.7  0.274  1992
# 1  ...   6.6  6.7  1.8  0.9  0.470  0.337  0.794  12.8  0.223  1992
# 2  ...  12.2  2.7  2.3  4.5  0.551  0.125  0.701  13.9  0.260  1992
# 3  ...  11.2  3.0  1.3  0.6  0.526  0.176  0.778  15.1  0.237  1992
# 4  ...  11.2  1.9  1.1  3.0  0.522  0.167  0.738  13.0  0.198  1992
#
# [5 rows x 21 columns]

# %%
mvps.to_csv("mvps.csv")

# %%
mvps
# Out:
#    Rank          Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 0     1  Michael Jordan   28  CHI   80.0    900.0      960  0.938  80  38.8
# 1     2   Clyde Drexler   29  POR   12.0    561.0      960  0.584  76  36.2
# 2     3  David Robinson   26  SAS    2.0    337.0      960  0.351  68  37.7
# 3     4     Karl Malone   28  UTA    1.0    262.0      960  0.273  81  37.7
# 4     5   Patrick Ewing   29  NYK    0.0    100.0      960  0.104  82  38.4
# ..  ...             ...  ...  ...    ...      ...      ...    ...  ..   ...
# 7     8   Stephen Curry   33  GSW    0.0      4.0     1000  0.004  64  34.5
# 8     9      Chris Paul   36  PHO    0.0      2.0     1000  0.002  65  32.9
# 9   10T   DeMar DeRozan   32  CHI    0.0      1.0     1000  0.001  76  36.1
# 10  10T    Kevin Durant   33  BRK    0.0      1.0     1000  0.001  55  37.2
# 11  10T    LeBron James   37  LAL    0.0      1.0     1000  0.001  56  37.2
#
# ...

# %%
player_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"

url = player_stats_url.format(year)
data = requests.get(url)
with open("player/{}.html", "w+", encoding="utf-8") as f:
        f.write(data.text.encode('ascii', 'ignore').decode('ascii'))

# %%
from selenium import webdriver

# %%
from selenium.webdriver.chrome.service import Service as ChromeService

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
for year in years:
    url = player_stats_url.format(year)

    driver.get(url)
    driver.execute_script("window.scrollTo(1, 10000)")
    time.sleep(4)

    with open("player/{}.html".format(year), "w+", encoding='utf-8') as f:
        f.write(driver.page_source)

# %%
dfs = []
for year in years:
    with open(f"player/{year}.html", encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_="thead").decompose()
    player_table = soup.find_all(id="per_game_stats")[0]

    if len(player_table) > 0:
        player_df = pd.read_html(str(player_table))[0]
        player_df["Year"] = year
        dfs.append(player_df)
time.sleep(20)

# %%
players = pd.concat(dfs)

# %%
players.head()
# Out:
#   Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  ORB  DRB  \
# 0  1      Alaa Abdelnaby  PF  23  POR  71   1  13.2  2.5   5.1  ...  1.1  2.5
# 1  2  Mahmoud Abdul-Rauf  PG  22  DEN  81  11  19.0  4.4  10.4  ...  0.3  1.1
# 2  3          Mark Acres   C  29  ORL  68   6  13.6  1.1   2.2  ...  1.4  2.3
# 3  4       Michael Adams  PG  29  WSB  78  78  35.8  6.2  15.8  ...  0.7  3.2
# 4  5      Rafael Addison  SF  27  NJN  76   8  15.5  2.5   5.7  ...  0.9  1.3
#
#    TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  3.7  0.4  0.4  0.2  0.9  1.9   6.1  1992
# 1  1.4  2.4  0.5  0.0  1.4  1.6  10.3  1992
# 2  3.7  0.3  0.4  0.2  0.5  2.1   3.1  1992
# 3  4.0  7.6  1.9  0.1  2.7  2.1  18.1  1992
# 4  2.2  0.9  0.4  0.4  0.6  1.4   5.8  1992
#
# [5 rows x 31 columns]

# %%
players.to_csv("players.csv")

# %%
team_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_standings.html"

# %% [markdown]
# Below is where we're adding the HTML pages to our team folder

# %%
for year in years:
        url =team_stats_url.format(year)

        data = requests.get(url)

        with open("team/{}.html".format(year), "w+", encoding="utf-8") as f:
                f.write(data.text)
time.sleep(15)

# %%
dfs = []
for year in years:
    with open("team/{}.html".format(year), encoding='utf-8') as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_="thead").decompose()
    e_table = soup.find_all(id="divs_standings_E")[0]
    e_df = pd.read_html(str(e_table))[0]
    e_df["Year"] = year
    e_df["Team"] = e_df["Eastern Conference"]
    del e_df["Eastern Conference"]
    dfs.append(e_df)
    
    w_table = soup.find_all(id="divs_standings_W")[0]
    w_df = pd.read_html(str(w_table))[0]
    w_df["Year"] = year
    w_df["Team"] = w_df["Western Conference"]
    del w_df["Western Conference"]
    dfs.append(w_df)
time.sleep(15)

# %%
teams = pd.concat(dfs)

# %%
teams.tail()
# Out:
#      W   L  W/L%    GB   PS/G   PA/G    SRS  Year                   Team
# 13  56  26  .683     —  115.6  109.9   5.37  2022     Memphis Grizzlies*
# 14  52  30  .634   4.0  108.0  104.7   3.12  2022      Dallas Mavericks*
# 15  36  46  .439  20.0  109.3  110.3  -0.84  2022  New Orleans Pelicans*
# 16  34  48  .415  22.0  113.2  113.0   0.02  2022      San Antonio Spurs
# 17  20  62  .244  36.0  109.7  118.2  -8.26  2022        Houston Rockets

# %%
teams.head()
# Out:
#     W   L  W/L%    GB   PS/G   PA/G    SRS  Year                Team
# 0  51  31  .622     —  106.6  103.0   3.41  1992     Boston Celtics*
# 1  51  31  .622     —  101.6   97.7   3.67  1992    New York Knicks*
# 2  40  42  .488  11.0  105.4  107.1  -1.54  1992    New Jersey Nets*
# 3  38  44  .463  13.0  105.0  109.2  -3.94  1992         Miami Heat*
# 4  35  47  .427  16.0  101.9  103.2  -1.34  1992  Philadelphia 76ers

# %%
teams.to_csv("teams.csv")
